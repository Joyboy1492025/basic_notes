# %%
import streamlib as st
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import streamlib as st
#
# ModuleNotFoundError: No module named 'streamlib'

# %%
import streamlit as st
streamlit.run("Select a value")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import streamlit as st
# ----> 2 streamlit.run("Select a value")
#
# NameError: name 'streamlit' is not defined
